# %%
import pandas as pd

# %%
excel_file_path = 'Qualifizierungsmodule_Qualifizierungspläne_v4 (1).xlsx'

# %%
df = pd.read_excel(excel_file_path, sheet_name='Tabelle1')

# %%
# Drop the first two rows
df = df.drop([0, 1]).reset_index(drop=True)

# Drop the first column
df = df.drop(df.columns[0], axis=1)

# %%
df.columns = df.iloc[0]

# %%
df = df.drop(0).reset_index(drop=True)

# %%
df.columns.values[0] = "Kompetenz"
df.columns.values[1] = "Definition"

# %%
df
# Out:
# 0                                       Kompetenz  \
# 0                             Systemisches Denken
# 1                 Systemmodellierung und -analyse
# 2   Berücksichtigung von Systemlebenszyklusphasen
# 3       Agiles Denken / Kunden-Nutzenorientierung
# 4                          Anforderungsmanagement
# 5                    System-Architekturgestaltung
# 6         Integration, Verifikation & Validierung
# 7             Betrieb, Service und Instandhaltung
# 8                         Agile Methodenkompetenz
# 9                              Selbstorganisation
# 10                 Kommunikation & Zusammenarbeit
# 11                                         Führen
# 12                              Projektmanagement
# 13                        Entscheidungsmanagement
# 14                         Informationsmanagement
# 15                       Konfigurationsmanagement
# 16                                Implementierung
#
# 0                                          Definition  \
# 0   Die Kompetenz fundamentale Konzepte des System...
# 1   Die Kompetenz exakte Daten und Informationen m...
# 2   Die Kompetenz während der Realisierung eines S...
# 3   Die Kompetenz die agilen Werte / den Kundennut...
# 4   Die Kompetenz  Bedürfnisse und Erwartungen der...
# 5   Die Kompetenz die zu einem System zugehörigen ...
# 6   Die Kompetenz eine Menge von Systemelementen z...
# 7   Die Kompetenz das System in Betrieb zu nehmen,...
# 8   Die Kompetenz Methoden anzuwenden, welche die ...
# 9   Die Kompetenz sich selbst zu organisieren und ...
# 10  Die Kompetenz konstruktiv, effizient und bewus...
# 11  Die Kompetenz geeignete Ziele für ein System b...
# 12  Die Kompetenz Aktivitäten zu identifizieren, p...
# 13  Die Kompetenz strukturiert und analytisch ein ...
# 14  Die Fähigkeit alle Aspekten von Informationen ...
# 15  Die Fähigkeit Systemfunktionen, Leistung und p...
# 16  Die Fähigkeit ein System, Subsystem, Komponent...
#
# 0                                              Kennen  \
# 0   Der Teilnehmer kennt die Zusammenhänge seines ...
# 1   Die Teilnehmer kennen die Grundlage der Modell...
# 2   Die Teilnehmer kennt die Lebenszyklusphasen se...
# 3   Die Teilnehmerin ikennt die Grundprinzipien de...
# 4   Prozess: Die Teilnehmer können Bedarfe,  Stake...
# 5   Prozess: Die Teilnehmer kennen den Zweck von A...
# 6   Der Teilnehmer kennt die Ziele der Verifikatio...
# 7   Die Teilnehmer kennen die Zeile der Betriebs-,...
# 8   Methode: Der Teilnehmer kennt die Agilen Werte...
# 9   Die Teilnehmer kennen die Konzepte der Selbsto...
# 10  Teilnehmer kennt die Notwendigkeit dieser Komp...
# 11  Teilnehmer kennt die Notwendigkeit dieser Komp...
# 12  Prozess: Der Teilnehmer kennt das Themenfeldpr...
# 13  Die Teilnehmer kennen die wesentlichen Entsche...
# 14  Der Teilnehmer kennt die Vorteile eines etabli...
# 15  Porzess. Der TN versteht die Notwendgkeit des ...
# 16                                                NaN
#
# 0                                           Verstehen  \
# 0   Der Teilnehmer versteht die Wechselwirkung der...
# 1   Die Teilnehmer verstehen wie Modelle ihre Arbe...
# 2   Der Teilnehmer verseht warum und wie alle Lebe...
# 3   Die Teilnehmerin versteht wie Agiles Denken in...
# 4   Prozess: Die Teilnehmer verstehen wie Anforder...
# 5   Prozess: Die Teilnehmer können nachvollziehen,...
# 6   Der Teilnehmer kann Testpläne, Testfälle und -...
# 7   Die Teilnehmer verstehen, wie die Phasen Betri...
# 8   Methode: Der Teilnehmer versteht die Grundlage...
# 9   Die Teilnehmer verstrehen wie die Konzepte der...
# 10  Teilnehmer erkennt und versteht die Relevanz d...
# 11  Teilnehmer versteht die Relevanz bzgl. der Def...
# 12  Prozess : Der Teilnehmer versteht den Projekta...
# 13  Die Teilnehmer lernen Entscheidungsunterstützu...
# 14  Der Teilnehmer kennt die wesentlichen Plattfor...
# 15  Prozess: Der Teilnehmer versteht das Vorgehen ...
# 16                                                NaN
#
# 0                                            Anwenden  \
# 0   Der Teilnehmer ist in der Lage, sein vorliegen...
# 1   Die Teilnehmer sind in der Lage eigene Systemm...
# 2   Der Teilmnehmer ist in der Lage für die für ih...
# 3   Die Teilnehmerin ist ind er Lage ein System na...
# 4   Prozess: Der Teilnehmer kann selbständig Anfor...
# 5   Prozess: Die Teilnehmer kennen relevante Proze...
# 6   Der Teilnehmer kann Testpläne erstellen. Er is...
# 7   Die Teilnehmer verstehen, wie die Phasen Betri...
# 8   Methode: der Teilnehmer kann in einem agilen U...
# 9   Die Teilnehmer sind in der Lage selbstorganisi...
# 10  Teilnehmer ist in der Lage konstruktiv und eff...
# 11  Teilnehmer ist in der Lage, die Ziele mit dem ...
# 12  Prozess & Methode: Der Teilnehmer ist in der L...
# 13  Die Teilnehmer sind in der Lage für ihre relev...
# 14  Der Teilnehmer kennt die wesentlichen Plattfor...
# 15  Prozess: Der Teilnehmer kann sinnvolle Konfigu...
# 16                                                NaN
#
# 0                                         Beherrschen
# 0   Der Teilnehmer ist in der Lage Systemisches De...
# 1   Die Teilnehmer können Vorgaben für (notwendige...
# 2   Der Teilnehmer ist in der Lage Konzepte hinsic...
# 3   Die Teilnehmerin ist in der Lage Agilkes Denke...
# 4   Prozess: Die Teilnehmer sind in der Lage Unzul...
# 5   Prozess: Die Teilnehmer sind in der Lage Unzul...
# 6   Der Teilnehmer ist in der Lage selbständig und...
# 7   Die Teilnehmer sind in der Lage die Organisati...
# 8   Der Teilnehmer kann für ein projekt die releva...
# 9   Die Teilnehmer sind in der Lage selbstorganisi...
# 10  Teilnehmer ist darüber hinaus in der Lage, sei...
# 11  Teilnehmer ist in der Lage, Teammitglieder str...
# 12  Prozess: Der Teilnehmer ist in der Lage Unzulä...
# 13  Die Teilnehmer können Entscheidungen bewerten ...
# 14  Der Teilnehmer kann einen umfangreichen Inform...
# 15  Prozess: Er ist fähig alle  relevanten Konfigu...
# 16                                                NaN

# %% [markdown]
# ## Generate indicators using LLM

# %%
import os
from pydantic import BaseModel, Field
from typing import List, Dict
from langchain.prompts import ChatPromptTemplate
from langchain_openai import AzureChatOpenAI

# %%
# --- Define the Pydantic model for competency indicators ---
class Indicator(BaseModel):
    english: str = Field(..., description="The indicator in English.")
    german: str = Field(..., description="The indicator in German.")

class CompetencyLevelIndicators(BaseModel):
    kennen: List[Indicator] = Field(..., description="List of indicators for level 'Kennen'.")
    verstehen: List[Indicator] = Field(..., description="List of indicators for level 'Verstehen'.")
    anwenden: List[Indicator] = Field(..., description="List of indicators for level 'Anwenden'.")
    beherrschen: List[Indicator] = Field(..., description="List of indicators for level 'Beherrschen'.")

class CompetencyIndicatorsResponse(BaseModel):
    competency_name: str = Field(..., description="Name of the competency.")
    indicators: CompetencyLevelIndicators = Field(..., description="Structured indicators for each competency level.")

    # Method to return JSON output
    def to_json(self):
        return self.model_dump()  # Convert the Pydantic model to a JSON-friendly dictionary

# %%
# Initialize the Azure OpenAI client
azure_endpoint = os.environ.get("AZURE_API_BASE")
api_key = os.environ.get("AZURE_API_KEY")

# %%
def init_llm():
    """
    Initialize the Azure OpenAI LLM.
    """
    return AzureChatOpenAI(
        model="gpt-4",
        openai_api_key=api_key,
        azure_endpoint=azure_endpoint,
        api_version="2024-02-01",
        temperature=0.7
    )

# %%
# --- Create the prompt for generating indicators ---
def create_competency_prompt():
    """
    Create a system and user prompt for generating competency indicators for each level in both English and German.
    """
    system_prompt = "You are an expert in systems engineering competency assessment."
    
    user_prompt = """
    I am creating a self-assessment survey for the competency "{competency_name}" with the following definition:
    
    "{competency_definition}"
    
    Please generate 1-2 user-friendly self-assessment indicators for each competency level ('Kennen', 'Verstehen', 'Anwenden', 'Beherrschen') in the format:
    
    'You are able to [do something]'.

    Each indicator should be provided in both English and German. Return the output in JSON format like this:
    {{
        "competency_name": "{competency_name}",
        "indicators": {{
            "kennen": [{{"english": "Indicator text", "german": "Indikator-Text"}}, ...],
            "verstehen": [{{"english": "Indicator text", "german": "Indikator-Text"}}, ...],
            "anwenden": [{{"english": "Indicator text", "german": "Indikator-Text"}}, ...],
            "beherrschen": [{{"english": "Indicator text", "german": "Indikator-Text"}}, ...]
        }}
    }}
    
    Here are the initial indicators for each level:
    {level_indicators}
    """

    return ChatPromptTemplate.from_messages(
        [
            ("system", system_prompt),
            ("user", user_prompt)
        ]
    )

# %%
# --- Create the competency chain ---
def create_competency_chain(llm,prompt):
    """
    Create the LangChain-style competency chain using the prompt and structured LLM.
    """
    prompt=prompt
    structured_llm = llm.with_structured_output(CompetencyIndicatorsResponse)
    return prompt | structured_llm

# %%
# --- Main function to generate indicators ---
def generate_competency_indicators(row):
    """
    Use the LLM to generate competency indicators and return the structured JSON.
    
    :param row: A row from the DataFrame containing competency information.
    :return: Competency indicators as structured JSON.
    """
    llm = init_llm()  # Initialize the LLM
    prompt = create_competency_prompt()  # Create the prompt
    competency_chain = create_competency_chain(llm,prompt)  # Create the competency chain
    #Prepare input to llm
    levels = ['Kennen', 'Verstehen', 'Anwenden', 'Beherrschen']
    level_indicators = "\n".join([f"{level.capitalize()} indicator: {row[level]}" for level in levels])

    inputs = {
        "competency_name": row['Kompetenz'],
        "competency_definition": row['Definition'],
        "level_indicators": level_indicators
    }
    # Run the competency chain
    result = competency_chain.invoke(inputs)
    
    # Return the structured response in JSON format
    return result.to_json()

# %%
df.columns = df.columns.str.strip()  # Strip any leading/trailing spaces

# %%
# Remove any potential index name from the columns
df.columns.name = None
# Process only the first row in the DataFrame for testing
first_row = df.iloc[0]  # Get the first row as a Series

# %%
print(first_row.index)  # This will show you the exact labels used in the Series
# Out:
# Index(['Kompetenz', 'Definition', 'Kennen', 'Verstehen', 'Anwenden',
#        'Beherrschen'],
#       dtype='object')

# %%
first_row['Kompetenz']
# Out:
# 'Systemisches Denken'

# %%
competency_name = first_row['Kompetenz']
competency_definition = first_row['Definition']
levels = ['Kennen', 'Verstehen', 'Anwenden', 'Beherrschen']
system_prompt = "You are an expert in systems engineering competency assessment."
levels = ['Kennen', 'Verstehen', 'Anwenden', 'Beherrschen']
user_prompt = f"""
    I am creating a self-assessment survey for the competency "{competency_name}" with the following definition:
    
    "{competency_definition}"
    
    Please generate 1-2 user-friendly self-assessment indicators for each competency level ('Kennen', 'Verstehen', 'Anwenden', 'Beherrschen') in the format:
    
    'You are able to [do something]'.

    Each indicator should be provided in both English and German. Return the output in JSON format like this:
    {{
        "competency_name": "{competency_name}",
        "indicators": {{
            "kennen": [{{"english": "Indicator text", "german": "Indikator-Text"}}, ...],
            "verstehen": [{{"english": "Indicator text", "german": "Indikator-Text"}}, ...],
            "anwenden": [{{"english": "Indicator text", "german": "Indikator-Text"}}, ...],
            "beherrschen": [{{"english": "Indicator text", "german": "Indikator-Text"}}, ...]
        }}
    }}
    
    Here are the initial indicators for each level:
    """
    # Append each level indicator from the row
for level in levels:
    user_prompt += f"\n{level.capitalize()} indicator: {first_row[level]}"

# %%
print(user_prompt)
# Out:
#     I am creating a self-assessment survey for the competency "Systemisches Denken" with the following definition:
#
#     "Die Kompetenz fundamentale Konzepte des Systemdenkens im Systems Engineering anzuwenden und die Rolle des eigenen Systems in seinem Gesamtkontext zu verstehen."
#
#     Please generate 1-2 user-friendly self-assessment indicators for each competency level ('Kennen', 'Verstehen', 'Anwenden', 'Beherrschen') in the format:
#
#     'You are able to [do something]'.
#
#     Each indicator should be provided in both English and German. Return the output in JSON format like this:
#     {
#         "competency_name": "Systemisches Denken",
#         "indicators": {
#             "kennen": [{"english": "Indicator text", "german": "Indikator-Text"}, ...],
#             "verstehen": [{"english": "Indicator text", "german": "Indikator-Text"}, ...],
#             "anwenden": [{"english": "Indicator text", "german": "Indikator-Text"}, ...],
#             "beherrschen": [{"english": "Indicator text", "german": "Indikator-Text"}, ...]
#         }
#     }
#
#     Here are the initial indicators for each level:
#
# Kennen indicator: Der Teilnehmer kennt die Zusammenhänge seines Systems und die dazugehörigen Systemgrenzen.
# Verstehen indicator: Der Teilnehmer versteht die Wechselwirkung der einezelnen Komponenten die das System ausmacht.
# Anwenden indicator: Der Teilnehmer ist in der Lage, sein vorliegendes System zu analysieren und daraus kontinuierliche Verbesserungen abzuleiten.
# Beherrschen indicator: Der Teilnehmer ist in der Lage Systemisches Denken in das Unternehmen zu tragen und andere dafür zu begeistern.

# %%
competency_json = generate_competency_indicators(first_row)
print(f"\nCompetency 1 JSON Output:\n{competency_json}\n")
# Out:
# Competency 1 JSON Output:
# {'competency_name': 'Systemisches Denken', 'indicators': {'kennen': [{'english': 'You are able to identify the relationships within your system and its boundaries.', 'german': 'Sie sind in der Lage, die Zusammenhänge Ihres Systems und die dazugehörigen Systemgrenzen zu erkennen.'}], 'verstehen': [{'english': 'You understand the interactions of the individual components that make up the system.', 'german': 'Sie verstehen die Wechselwirkungen der einzelnen Komponenten, die das System ausmachen.'}], 'anwenden': [{'english': 'You are able to analyze your existing system and derive continuous improvements from it.', 'german': 'Sie sind in der Lage, Ihr vorhandenes System zu analysieren und daraus kontinuierliche Verbesserungen abzuleiten.'}], 'beherrschen': [{'english': 'You are able to carry systemic thinking into the company and inspire others for it.', 'german': 'Sie sind in der Lage, systemisches Denken in das Unternehmen zu tragen und andere dafür zu begeistern.'}]}}

# %%
import psycopg2
import json

# %%
conn = psycopg2.connect(
    host=os.environ.get("POSTGRES_HOST"),
    database=os.environ.get("POSTGRES_DB"),
    user=os.environ.get("POSTGRES_USER"),
    password=os.environ.get("POSTGRES_PASSWORD")
)
cur = conn.cursor()

# %%
# Step 3: Query the competency table to create a lookup for competency IDs
cur.execute("SELECT id, competency_name FROM public.competency;")
competency_id_lookup = {row[1]: row[0] for row in cur.fetchall()}

# %%
competency_id_lookup
# Out:
# {'Systems Thinking': 1,
#  'Lifecycle Consideration': 4,
#  'Customer / Value Orientation': 5,
#  'Systems Modeling and Analysis': 6,
#  'Communication': 7,
#  'Leadership': 8,
#  'Self-Organization': 9,
#  'Project Management': 10,
#  'Decision Management': 11,
#  'Information Management': 12,
#  'Configuration Management': 13,
#  'Requirements Definition': 14,
#  'System Architecting': 15,
#  'Integration, Verification,  Validation': 16,
#  'Operation and Support': 17,
#  'Agile Methods': 18}

# %%
# Create a mapping of English competency names to German equivalents
competency_mapping = {
    "Systems Thinking": "Systemisches Denken",
    "Lifecycle Consideration": "Berücksichtigung von Systemlebenszyklusphasen",
    "Customer / Value Orientation": "Agiles Denken / Kunden-Nutzenorientierung",
    "Systems Modeling and Analysis": "Systemmodellierung und -analyse",
    "Communication": "Kommunikation & Zusammenarbeit",
    "Leadership": "Führen",
    "Self-Organization": "Selbstorganisation",
    "Project Management": "Projektmanagement",
    "Decision Management": "Entscheidungsmanagement",
    "Information Management": "Informationsmanagement",
    "Configuration Management": "Konfigurationsmanagement",
    "Requirements Definition": "Anforderungsmanagement",
    "System Architecting": "System-Architekturgestaltung",
    "Integration, Verification,  Validation": "Integration, Verifikation & Validierung",
    "Operation and Support": "Betrieb, Service und Instandhaltung",
    "Agile Methods": "Agile Methodenkompetenz",
    "Implementation": "Implementierung"
}

# %%
# Verify if all German names from LLM can be matched with English names in competency_id_lookup
print("\nVerifying if German names match English names:")
unmatched_german_names = []

for german_name in competency_mapping.values():
    matched_english_name = next((eng_name for eng_name, ger_name in competency_mapping.items() if ger_name == german_name), None)
    if matched_english_name and matched_english_name in competency_id_lookup:
        print(f"German Competency '{german_name}' successfully matched to English Competency '{matched_english_name}' with ID {competency_id_lookup[matched_english_name]}")
    else:
        unmatched_german_names.append(german_name)

# Print any unmatched German names
if unmatched_german_names:
    print("\nUnmatched German Competency Names:")
    for name in unmatched_german_names:
        print(f"'{name}'")
else:
    print("\nAll German competency names matched successfully.")
# Out:
# Verifying if German names match English names:
# German Competency 'Systemisches Denken' successfully matched to English Competency 'Systems Thinking' with ID 1
# German Competency 'Berücksichtigung von Systemlebenszyklusphasen' successfully matched to English Competency 'Lifecycle Consideration' with ID 4
# German Competency 'Agiles Denken / Kunden-Nutzenorientierung' successfully matched to English Competency 'Customer / Value Orientation' with ID 5
# German Competency 'Systemmodellierung und -analyse' successfully matched to English Competency 'Systems Modeling and Analysis' with ID 6
# German Competency 'Kommunikation & Zusammenarbeit' successfully matched to English Competency 'Communication' with ID 7
# German Competency 'Führen' successfully matched to English Competency 'Leadership' with ID 8
# German Competency 'Selbstorganisation' successfully matched to English Competency 'Self-Organization' with ID 9
# German Competency 'Projektmanagement' successfully matched to English Competency 'Project Management' with ID 10
# German Competency 'Entscheidungsmanagement' successfully matched to English Competency 'Decision Management' with ID 11
# German Competency 'Informationsmanagement' successfully matched to English Competency 'Information Management' with ID 12
# German Competency 'Konfigurationsmanagement' successfully matched to English Competency 'Configuration Management' with ID 13
# German Competency 'Anforderungsmanagement' successfully matched to English Competency 'Requirements Definition' with ID 14
# German Competency 'System-Architekturgestaltung' successfully matched to English Competency 'System Architecting' with ID 15
# German Competency 'Integration, Verifikation & Validierung' successfully matched to English Competency 'Integration, Verification,  Validation' with ID 16
# German Competency 'Betrieb, Service und Instandhaltung' successfully matched to English Competency 'Operation and Support' with ID 17
# German Competency 'Agile Methodenkompetenz' successfully matched to English Competency 'Agile Methods' with ID 18
#
# Unmatched German Competency Names:
# 'Implementierung'

# %%
df
# Out:
#                                         Kompetenz  \
# 0                             Systemisches Denken
# 1                 Systemmodellierung und -analyse
# 2   Berücksichtigung von Systemlebenszyklusphasen
# 3       Agiles Denken / Kunden-Nutzenorientierung
# 4                          Anforderungsmanagement
# 5                    System-Architekturgestaltung
# 6         Integration, Verifikation & Validierung
# 7             Betrieb, Service und Instandhaltung
# 8                         Agile Methodenkompetenz
# 9                              Selbstorganisation
# 10                 Kommunikation & Zusammenarbeit
# 11                                         Führen
# 12                              Projektmanagement
# 13                        Entscheidungsmanagement
# 14                         Informationsmanagement
# 15                       Konfigurationsmanagement
# 16                                Implementierung
#
#                                            Definition  \
# 0   Die Kompetenz fundamentale Konzepte des System...
# 1   Die Kompetenz exakte Daten und Informationen m...
# 2   Die Kompetenz während der Realisierung eines S...
# 3   Die Kompetenz die agilen Werte / den Kundennut...
# 4   Die Kompetenz  Bedürfnisse und Erwartungen der...
# 5   Die Kompetenz die zu einem System zugehörigen ...
# 6   Die Kompetenz eine Menge von Systemelementen z...
# 7   Die Kompetenz das System in Betrieb zu nehmen,...
# 8   Die Kompetenz Methoden anzuwenden, welche die ...
# 9   Die Kompetenz sich selbst zu organisieren und ...
# 10  Die Kompetenz konstruktiv, effizient und bewus...
# 11  Die Kompetenz geeignete Ziele für ein System b...
# 12  Die Kompetenz Aktivitäten zu identifizieren, p...
# 13  Die Kompetenz strukturiert und analytisch ein ...
# 14  Die Fähigkeit alle Aspekten von Informationen ...
# 15  Die Fähigkeit Systemfunktionen, Leistung und p...
# 16  Die Fähigkeit ein System, Subsystem, Komponent...
#
#                                                Kennen  \
# 0   Der Teilnehmer kennt die Zusammenhänge seines ...
# 1   Die Teilnehmer kennen die Grundlage der Modell...
# 2   Die Teilnehmer kennt die Lebenszyklusphasen se...
# 3   Die Teilnehmerin ikennt die Grundprinzipien de...
# 4   Prozess: Die Teilnehmer können Bedarfe,  Stake...
# 5   Prozess: Die Teilnehmer kennen den Zweck von A...
# 6   Der Teilnehmer kennt die Ziele der Verifikatio...
# 7   Die Teilnehmer kennen die Zeile der Betriebs-,...
# 8   Methode: Der Teilnehmer kennt die Agilen Werte...
# 9   Die Teilnehmer kennen die Konzepte der Selbsto...
# 10  Teilnehmer kennt die Notwendigkeit dieser Komp...
# 11  Teilnehmer kennt die Notwendigkeit dieser Komp...
# 12  Prozess: Der Teilnehmer kennt das Themenfeldpr...
# 13  Die Teilnehmer kennen die wesentlichen Entsche...
# 14  Der Teilnehmer kennt die Vorteile eines etabli...
# 15  Porzess. Der TN versteht die Notwendgkeit des ...
# 16                                                NaN
#
#                                             Verstehen  \
# 0   Der Teilnehmer versteht die Wechselwirkung der...
# 1   Die Teilnehmer verstehen wie Modelle ihre Arbe...
# 2   Der Teilnehmer verseht warum und wie alle Lebe...
# 3   Die Teilnehmerin versteht wie Agiles Denken in...
# 4   Prozess: Die Teilnehmer verstehen wie Anforder...
# 5   Prozess: Die Teilnehmer können nachvollziehen,...
# 6   Der Teilnehmer kann Testpläne, Testfälle und -...
# 7   Die Teilnehmer verstehen, wie die Phasen Betri...
# 8   Methode: Der Teilnehmer versteht die Grundlage...
# 9   Die Teilnehmer verstrehen wie die Konzepte der...
# 10  Teilnehmer erkennt und versteht die Relevanz d...
# 11  Teilnehmer versteht die Relevanz bzgl. der Def...
# 12  Prozess : Der Teilnehmer versteht den Projekta...
# 13  Die Teilnehmer lernen Entscheidungsunterstützu...
# 14  Der Teilnehmer kennt die wesentlichen Plattfor...
# 15  Prozess: Der Teilnehmer versteht das Vorgehen ...
# 16                                                NaN
#
#                                              Anwenden  \
# 0   Der Teilnehmer ist in der Lage, sein vorliegen...
# 1   Die Teilnehmer sind in der Lage eigene Systemm...
# 2   Der Teilmnehmer ist in der Lage für die für ih...
# 3   Die Teilnehmerin ist ind er Lage ein System na...
# 4   Prozess: Der Teilnehmer kann selbständig Anfor...
# 5   Prozess: Die Teilnehmer kennen relevante Proze...
# 6   Der Teilnehmer kann Testpläne erstellen. Er is...
# 7   Die Teilnehmer verstehen, wie die Phasen Betri...
# 8   Methode: der Teilnehmer kann in einem agilen U...
# 9   Die Teilnehmer sind in der Lage selbstorganisi...
# 10  Teilnehmer ist in der Lage konstruktiv und eff...
# 11  Teilnehmer ist in der Lage, die Ziele mit dem ...
# 12  Prozess & Methode: Der Teilnehmer ist in der L...
# 13  Die Teilnehmer sind in der Lage für ihre relev...
# 14  Der Teilnehmer kennt die wesentlichen Plattfor...
# 15  Prozess: Der Teilnehmer kann sinnvolle Konfigu...
# 16                                                NaN
#
#                                           Beherrschen
# 0   Der Teilnehmer ist in der Lage Systemisches De...
# 1   Die Teilnehmer können Vorgaben für (notwendige...
# 2   Der Teilnehmer ist in der Lage Konzepte hinsic...
# 3   Die Teilnehmerin ist in der Lage Agilkes Denke...
# 4   Prozess: Die Teilnehmer sind in der Lage Unzul...
# 5   Prozess: Die Teilnehmer sind in der Lage Unzul...
# 6   Der Teilnehmer ist in der Lage selbständig und...
# 7   Die Teilnehmer sind in der Lage die Organisati...
# 8   Der Teilnehmer kann für ein projekt die releva...
# 9   Die Teilnehmer sind in der Lage selbstorganisi...
# 10  Teilnehmer ist darüber hinaus in der Lage, sei...
# 11  Teilnehmer ist in der Lage, Teammitglieder str...
# 12  Prozess: Der Teilnehmer ist in der Lage Unzulä...
# 13  Die Teilnehmer können Entscheidungen bewerten ...
# 14  Der Teilnehmer kann einen umfangreichen Inform...
# 15  Prozess: Er ist fähig alle  relevanten Konfigu...
# 16                                                NaN

# %%
# Process each row in the DataFrame and get the structured JSON output
for index, row in df.iterrows():
    # Skip the iteration if the 'Kompetenz' column has the value 'Implementierung'
    if row['Kompetenz'] == 'Implementierung':
        print(f"Skipping row {index + 1} as it is 'Implementierung'")
        continue

    llm_output = generate_competency_indicators(row)
    print(f"\nCompetency {index + 1} JSON Output:\n{llm_output}\n")
    
    # Get the competency_id using the German name
    german_competency_name = llm_output['competency_name']
    english_competency_name = next((eng_name for eng_name, ger_name in competency_mapping.items() if ger_name == german_competency_name), None)
    competency_id = competency_id_lookup.get(english_competency_name)
    
    if competency_id:
        for level, indicators in llm_output['indicators'].items():
            for indicator in indicators:
                # Extract English and German indicators
                indicator_en = indicator['english']
                indicator_de = indicator['german']
                
                # Insert each indicator into the modified table
                cur.execute(
                    "INSERT INTO public.competency_indicators (competency_id, level, indicator_en, indicator_de) VALUES (%s, %s, %s, %s)",
                    (competency_id, level, indicator_en, indicator_de)
                )
        conn.commit()
        print(f"Inserted indicators for competency '{english_competency_name}'")
    else:
        print(f"Competency '{german_competency_name}' not found in mapping")
# Out:
# Competency 1 JSON Output:
# {'competency_name': 'Systemisches Denken', 'indicators': {'kennen': [{'english': 'You are able to recognize the interrelationships of your system and its boundaries.', 'german': 'Sie kennen die Zusammenhänge Ihres Systems und die dazugehörigen Systemgrenzen.'}], 'verstehen': [{'english': 'You understand the interaction of the individual components that make up the system.', 'german': 'Sie verstehen die Wechselwirkung der einzelnen Komponenten, die das System ausmachen.'}], 'anwenden': [{'english': 'You are able to analyze your present system and derive continuous improvements from it.', 'german': 'Sie sind in der Lage, Ihr vorliegendes System zu analysieren und daraus kontinuierliche Verbesserungen abzuleiten.'}], 'beherrschen': [{'english': 'You are able to carry systemic thinking into the company and inspire others for it.', 'german': 'Sie sind in der Lage, systemisches Denken in das Unternehmen zu tragen und andere dafür zu begeistern.'}]}}
#
# Inserted indicators for competency 'Systems Thinking'
#
# Competency 2 JSON Output:
# {'competency_name': 'Systemmodellierung und -analyse', 'indicators': {'kennen': [{'english': 'You are familiar with the basics of modeling and its benefits.', 'german': 'Sie kennen die Grundlagen der Modellierung und deren Vorteile.'}], 'verstehen': [{'english': 'You understand how models support your work and are able to read simple models.', 'german': 'Sie verstehen, wie Modelle Ihre Arbeit unterstützen und sind in der Lage, einfache Modelle zu lesen.'}], 'anwenden': [{'english': 'You are able to define your own system models for the relevant scope independently and can differentiate between cross-domain and domain-specific models.', 'german': 'Sie sind in der Lage, eigene Systemmodelle für ihren relevanten Umfang eigenständig zu definieren und können zwischen domänen-übergreifenden und domänenspezifischen Modellen unterscheiden.'}], 'beherrschen': [{'english': 'You can set guidelines for necessary models and write guidelines for good modeling practices.', 'german': 'Sie können Vorgaben für notwendige Modelle machen und Richtlinien für gute Modellierung schreiben.'}]}}
#
# Inserted indicators for competency 'Systems Modeling and Analysis'
#
# Competency 3 JSON Output:
# {'competency_name': 'Berücksichtigung von Systemlebenszyklusphasen', 'indicators': {'kennen': [{'english': 'You are able to identify the lifecycle phases of your system.', 'german': 'Sie kennen die Lebenszyklusphasen Ihres Systems.'}], 'verstehen': [{'english': 'You understand why and how all lifecycle phases need to be considered during development.', 'german': 'Sie verstehen, warum und wie alle Lebenszyklusphasen im Rahmen der Entwicklung berücksichtigt werden müssen.'}], 'anwenden': [{'english': 'You are able to identify, consider, and assess all lifecycle phases relevant to your scope.', 'german': 'Sie sind in der Lage, alle für Ihren Umfang relevanten Lebenszyklusphasen zu identifizieren, zu berücksichtigen und zu bewerten.'}], 'beherrschen': [{'english': 'You are able to evaluate concepts regarding the consideration of all lifecycle phases.', 'german': 'Sie sind in der Lage, Konzepte hinsichtlich der Berücksichtigung von allen Lebenszyklusphasen zu bewerten.'}]}}
#
# Inserted indicators for competency 'Lifecycle Consideration'
#
# Competency 4 JSON Output:
# {'competency_name': 'Agiles Denken / Kunden-Nutzenorientierung', 'indicators': {'kennen': [{'english': 'You are able to identify the fundamental principles of agile thinking.', 'german': 'Sie kennen die Grundprinzipien des agilen Denkens.'}], 'verstehen': [{'english': 'You understand how to integrate agile thinking into daily work.', 'german': 'Sie verstehen, wie agiles Denken in den Arbeitsalltag integriert werden kann.'}], 'anwenden': [{'english': 'You are able to develop a system using agile methodologies and focus on customer benefit.', 'german': 'Sie sind in der Lage, ein System nach agilen Denkweisen zu entwickeln und den Kundennutzen in den Mittelpunkt zu stellen.'}], 'beherrschen': [{'english': 'You are able to promote agile thinking within the organization and inspire others.', 'german': 'Sie sind in der Lage, agiles Denken im Unternehmen zu tragen und andere dafür zu begeistern.'}]}}
#
# Inserted indicators for competency 'Customer / Value Orientation'
#
# Competency 5 JSON Output:
# {'competency_name': 'Anforderungsmanagement', 'indicators': {'kennen': [{'english': 'You are able to distinguish between needs, stakeholder requirements, system requirements, and system element requirements. You understand the importance of traceability and why tools are necessary for it.', 'german': 'Sie können zwischen Bedürfnissen, Stakeholderanforderungen, Systemanforderungen und Systemelementanforderungen unterscheiden. Sie verstehen die Bedeutung der Nachverfolgbarkeit und warum Werkzeuge dafür notwendig sind.'}, {'english': 'You know the basic process of requirement management including identifying, formulating, deriving and analyzing requirements.', 'german': 'Sie kennen den grundlegenden Ablauf des Anforderungsmanagements, einschließlich des Identifizierens, Formulierens, Ableitens und Analysierens von Anforderungen.'}], 'verstehen': [{'english': 'You understand how to identify sources of requirements, derive and write them. You know the different types and levels of requirements.', 'german': 'Sie verstehen, wie Anforderungsquellen identifiziert, Anforderungen abgeleitet und geschrieben werden. Sie kennen die unterschiedlichen Arten und Ebenen von Anforderungen.'}, {'english': 'You can read requirement documents or models (links, etc.). You can read and understand context descriptions and interface specifications.', 'german': 'Sie können Anforderungsdokumente oder -modelle lesen (Verknüpfungen usw.). Sie können Kontextbeschreibungen und Schnittstellenspezifikationen lesen und verstehen.'}], 'anwenden': [{'english': 'You can independently identify sources of requirements, derive, write, and document requirements in documents or models, link, derive, and analyze them.', 'german': 'Sie können selbständig Anforderungsquellen identifizieren, Anforderungen daraus ableiten, schreiben, in Anforderungsdokumenten oder -modellen dokumentieren, verknüpfen, ableiten und analysieren.'}, {'english': 'You can independently document, link, and analyze requirement documents or models. You can create and analyze context descriptions and interface specifications.', 'german': 'Sie können selbständig Anforderungsdokumente oder -modelle dokumentieren, verknüpfen und analysieren. Sie können Kontextbeschreibungen und Schnittstellenspezifikationen erstellen und analysieren.'}], 'beherrschen': [{'english': 'You are able to recognize deficiencies in the process and develop suggestions for improvement.', 'german': 'Sie sind in der Lage, Unzulänglichkeiten im Prozess zu erkennen und Verbesserungsvorschläge zu erarbeiten.'}, {'english': 'You can create context and interface descriptions and discuss these with stakeholders.', 'german': 'Sie können Kontext- und Schnittstellenbeschreibungen erstellen und diese mit Stakeholdern diskutieren.'}]}}
#
# Inserted indicators for competency 'Requirements Definition'
#
# Competency 6 JSON Output:
# {'competency_name': 'System-Architekturgestaltung', 'indicators': {'kennen': [{'english': 'You are aware of the purpose of architectural models and can broadly categorize them in the development process.', 'german': 'Sie kennen den Zweck von Architekturmodellen und können sie grob in den Entwicklungsprozess einordnen.'}, {'english': 'You know that there is a dedicated methodology and modeling language for architectural modeling.', 'german': 'Sie wissen, dass es eine dedizierte Methodik und Modellierungssprache zur Architekturmodellierung gibt.'}], 'verstehen': [{'english': 'You understand why architectural models are relevant as inputs and outputs of the development process.', 'german': 'Sie können nachvollziehen, warum Architekturmodelle als Inputs und Outputs des Entwicklungsprozesses relevant sind.'}, {'english': 'You can read architectural models and extract relevant information from them.', 'german': 'Sie können Architekturmodelle lesen und daraus relevante Informationen entnehmen.'}], 'anwenden': [{'english': 'You know the relevant process steps for architectural models, where their inputs come from, and the outputs they produce within the development process.', 'german': 'Sie kennen relevante Prozessschritte für Architekturmodelle und wissen, woher ihre Inputs kommen und welche Outputs sie im Entwicklungsprozess produzieren.'}, {'english': 'You can create architectural models of average complexity, ensuring the information is reproducible and aligned with the methodology and modeling language.', 'german': 'Sie können Architekturmodelle von durchschnittlicher Komplexität erstellen. Sie sind in der Lage, relevante Informationen reproduzierbar und im Einklang mit der Methode und Modellierungssprache abzubilden.'}], 'beherrschen': [{'english': 'You can identify shortcomings in the process and develop suggestions for improvement.', 'german': 'Sie sind in der Lage, Unzulänglichkeiten im Prozess zu erkennen und Verbesserungsvorschläge zu erarbeiten.'}, {'english': 'You are capable of creating and managing highly complex models, recognizing deficiencies in the method or modeling language, and suggesting improvements.', 'german': 'Sie sind in der Lage, Modelle von hoher Komplexität zu erstellen und zu verwalten. Sie können Unzulänglichkeiten in der Methode oder der Modellierungssprache erkennen und Verbesserungsvorschläge erarbeiten.'}]}}
#
# Inserted indicators for competency 'System Architecting'
#
# Competency 7 JSON Output:
# {'competency_name': 'Integration, Verifikation & Validierung', 'indicators': {'kennen': [{'english': 'You are aware of the objectives of verification and validation and know various types and approaches of V&V.', 'german': 'Sie kennen die Ziele der Verifikation und Validierung sowie verschiedene Arten und Vorgehensweisen der V&V.'}], 'verstehen': [{'english': 'You can read and understand test plans, test cases, and results.', 'german': 'Sie können Testpläne, Testfälle und -ergebnisse lesen und verstehen.'}], 'anwenden': [{'english': 'You can create test plans and are capable of conducting and documenting tests and simulations.', 'german': 'Sie können Testpläne erstellen und sind in der Lage, Tests und Simulationen durchzuführen und zu dokumentieren.'}], 'beherrschen': [{'english': 'You are able to independently and proactively set up a testing strategy and an experimental plan. Based on requirements and verification/validation criteria, you can derive necessary test cases and orchestrate and document the tests and simulations.', 'german': 'Sie sind in der Lage, selbständig und frühzeitig eine Teststrategie sowie einen Erprobungsplan aufzusetzen. Anhand der Anforderungen und Verifikation/Validierungskriterien können Sie notwendige Testfälle ableiten und die Tests sowie Simulationen orchestrieren und dokumentieren.'}]}}
#
# Inserted indicators for competency 'Integration, Verification,  Validation'
#
# Competency 8 JSON Output:
# {'competency_name': 'Betrieb, Service und Instandhaltung', 'indicators': {'kennen': [{'english': 'You are familiar with the stages of operation, service, and maintenance phases. You understand these are considered during development and involve activities in each phase.', 'german': 'Sie kennen die Phasen des Betriebs, des Services und der Instandhaltung. Sie verstehen, dass diese bereits in der Entwicklung berücksichtigt werden und dass es Tätigkeiten in der jeweiligen Phase gibt.'}], 'verstehen': [{'english': 'You understand how the operation, service, and maintenance phases are integrated into the development. You are able to list the activities required throughout the lifecycle.', 'german': 'Sie verstehen, wie die Phasen Betrieb, Service und Instandhaltung in der Entwicklung berücksichtigt werden. Sie sind in der Lage, die im Rahmen des Lebenszyklus notwendigen Tätigkeiten zu nennen.'}], 'anwenden': [{'english': 'You can execute the operation, service, and maintenance phases and identify improvements for future projects.', 'german': 'Sie können die Phasen Betrieb, Service und Instandhaltung abwickeln und Verbesserungen für zukünftige Projekte identifizieren.'}], 'beherrschen': [{'english': 'You are able to define organizational processes for operation, maintenance, and servicing.', 'german': 'Sie sind in der Lage, die Organisationsprozesse für den Betrieb, die Wartung und die Instandhaltung zu definieren.'}]}}
#
# Inserted indicators for competency 'Operation and Support'
#
# Competency 9 JSON Output:
# {'competency_name': 'Agile Methodenkompetenz', 'indicators': {'kennen': [{'english': 'You are able to recognize and list the Agile values and relevant Agile methods.', 'german': 'Sie können die agilen Werte erkennen und die relevanten agilen Methoden auflisten.'}, {'english': 'You are aware of the basic principles of Agile methodologies.', 'german': 'Sie kennen die Grundprinzipien agiler Methodologien.'}], 'verstehen': [{'english': 'You understand the fundamentals of Agile workflows and how to apply Agile methods within a development process.', 'german': 'Sie verstehen die Grundlagen agiler Arbeitsweisen und wie sich die agilen Methoden in einem Entwicklungsprozess anwenden lassen.'}, {'english': 'You are able to explain the impact of Agile practices on project success.', 'german': 'Sie können die Auswirkungen agiler Praktiken auf den Projekterfolg erklären.'}], 'anwenden': [{'english': 'You can effectively work in an Agile environment and apply the necessary methods.', 'german': 'Sie können effektiv in einem agilen Umfeld arbeiten und die dafür notwendigen Methoden anwenden.'}, {'english': 'You are able to adapt Agile techniques to various project scenarios.', 'german': 'Sie können agile Techniken an verschiedene Projektszenarien anpassen.'}], 'beherrschen': [{'english': 'You can define and implement the relevant Agile methods for a project, and are convinced of the benefits of using Agile methods.', 'german': 'Sie können die relevanten agilen Methoden für ein Projekt definieren und umsetzen und sind überzeugt von den Vorteilen des Einsatzes agiler Methoden.'}, {'english': 'You can motivate others to adopt Agile methods and lead Agile teams successfully.', 'german': 'Sie können andere dazu motivieren, agile Methoden anzuwenden, und agile Teams erfolgreich führen.'}]}}
#
# Inserted indicators for competency 'Agile Methods'
#
# Competency 10 JSON Output:
# {'competency_name': 'Selbstorganisation', 'indicators': {'kennen': [{'english': 'You are aware of the concepts of self-organization.', 'german': 'Sie kennen die Konzepte der Selbstorganisation.'}], 'verstehen': [{'english': 'You understand how self-organization concepts can influence your daily work.', 'german': 'Sie verstehen, wie die Konzepte der Selbstorganisation Ihren Arbeitsalltag beeinflussen können.'}], 'anwenden': [{'english': 'You are able to independently manage projects, processes, and tasks using self-organization skills.', 'german': 'Sie sind in der Lage, Projekte, Prozesse und Aufgaben selbstorganisiert abzuarbeiten.'}], 'beherrschen': [{'english': 'You can masterfully manage and optimize complex projects and processes through self-organization.', 'german': 'Sie können komplexe Projekte und Prozesse durch Selbstorganisation meisterhaft verwalten und optimieren.'}]}}
#
# Inserted indicators for competency 'Self-Organization'
#
# Competency 11 JSON Output:
# {'competency_name': 'Kommunikation & Zusammenarbeit', 'indicators': {'kennen': [{'english': 'You are aware of the necessity of these competencies.', 'german': 'Sie kennen die Notwendigkeit dieser Kompetenzen.'}], 'verstehen': [{'english': 'You recognize and understand the relevance of this competency, especially in terms of its application in systems engineering.', 'german': 'Sie erkennen und verstehen die Relevanz dieser Kompetenz, insbesondere im Hinblick auf die Anwendung im Systems Engineering.'}], 'anwenden': [{'english': 'You are able to communicate constructively and efficiently while being empathetic towards your communication partner.', 'german': 'Sie sind in der Lage, konstruktiv und effizient zu kommunizieren und gleichzeitig empathisch gegenüber Ihrem Kommunikationspartner zu sein.'}], 'beherrschen': [{'english': 'You are able to sustain and fairly manage your relationships with colleagues and supervisors.', 'german': 'Sie sind darüber hinaus in der Lage, Ihre Beziehungen zu Kollegen und Vorgesetzten nachhaltig und fair zu gestalten.'}]}}
#
# Inserted indicators for competency 'Communication'
#
# Competency 12 JSON Output:
# {'competency_name': 'Führen', 'indicators': {'kennen': [{'english': 'You are aware of the necessity of leadership competencies.', 'german': 'Sie kennen die Notwendigkeit von Führungskompetenzen.'}], 'verstehen': [{'english': 'You understand the relevance of defining objectives for a system and can articulate these objectives clearly to the entire team.', 'german': 'Sie verstehen die Bedeutung der Definition von Zielen für ein System und können diese für das gesamte Team verständlich definieren.'}], 'anwenden': [{'english': 'You are able to negotiate objectives with your team and find an efficient path to achieve them.', 'german': 'Sie sind in der Lage, Ziele mit dem Team zu verhandeln und einen effizienten Weg zur Erreichung dieser zu finden.'}], 'beherrschen': [{'english': 'You are able to strategically develop team members so that they evolve in their problem-solving capabilities.', 'german': 'Sie sind in der Lage, Teammitglieder strategisch weiterzuentwickeln, sodass diese sich bei der Lösungsfindung weiterentwickeln.'}]}}
#
# Inserted indicators for competency 'Leadership'
#
# Competency 13 JSON Output:
# {'competency_name': 'Projektmanagement', 'indicators': {'kennen': [{'english': 'You are able to identify your activities within a project plan.', 'german': 'Sie können Ihre Tätigkeiten in einem Projektplan einordnen.'}, {'english': 'You are familiar with common project management methods.', 'german': 'Sie kennen die gängigen Methoden des Projektmanagements.'}], 'verstehen': [{'english': 'You understand the project mandate and can contextualize project management within systems engineering.', 'german': 'Sie verstehen den Projektauftrag und können das Projektmanagement im Kontext des System Engineerings einordnen.'}, {'english': 'You can create relevant project plans and generate corresponding status reports independently.', 'german': 'Sie können eigenständig die für Sie relevanten Projektpläne erstellen und entsprechende Statusberichte erzeugen.'}], 'anwenden': [{'english': 'You are able to define a project mandate, establish conditions, create complex project plans, and produce meaningful reports.', 'german': 'Sie sind in der Lage, einen Projektauftrag zu definieren, Rahmenbedingungen festzulegen, komplexe Projektpläne zu erstellen und aussagekräftige Berichte zu erzeugen.'}, {'english': 'You are skilled in communicating with stakeholders.', 'german': 'In der Kommunikation mit Stakeholdern sind Sie geübt.'}], 'beherrschen': [{'english': 'You can identify inadequacies in the process and suggest improvements.', 'german': 'Sie sind in der Lage, Unzulänglichkeiten im Prozess zu identifizieren und Verbesserungsvorschläge zu machen.'}, {'english': 'You can successfully communicate reports, plans, and mandates to all stakeholders.', 'german': 'Sie sind in der Lage, Berichte, Pläne und Aufträge erfolgreich an alle Stakeholder zu kommunizieren.'}]}}
#
# Inserted indicators for competency 'Project Management'
#
# Competency 14 JSON Output:
# {'competency_name': 'Entscheidungsmanagement', 'indicators': {'kennen': [{'english': 'You are aware of the main decision-making bodies and understand how decisions are made.', 'german': 'Sie kennen die wesentlichen Entscheidungsgremien und wissen, wie Entscheidungen getroffen werden.'}], 'verstehen': [{'english': 'You understand decision support methods and know which decisions you can make yourself and which are made by committees.', 'german': 'Sie verstehen Entscheidungsunterstützungsmethoden und wissen, welche Entscheidungen Sie selbst treffen können und welche von Gremien getroffen werden.'}], 'anwenden': [{'english': 'You are able to prepare or make decisions for your relevant scopes and document them accordingly. You can apply decision support methods, such as utility analysis.', 'german': 'Sie sind in der Lage, Entscheidungen für Ihre relevanten Bereiche vorzubereiten oder selbst zu treffen und diese entsprechend zu dokumentieren. Sie können Methoden der Entscheidungsunterstützung, wie z.B. Nutzwertanalyse, anwenden.'}], 'beherrschen': [{'english': 'You can evaluate decisions and are able to define and establish overarching decision-making bodies. You can define good guidelines for making decisions.', 'german': 'Sie können Entscheidungen bewerten und sind in der Lage, übergreifende Entscheidungsgremien zu definieren und zu etablieren. Sie können gute Richtlinien für das Treffen von Entscheidungen definieren.'}]}}
#
# Inserted indicators for competency 'Decision Management'
#
# Competency 15 JSON Output:
# {'competency_name': 'Informationsmanagement', 'indicators': {'kennen': [{'english': 'You are aware of the benefits of established information and knowledge management.', 'german': 'Sie kennen die Vorteile eines etablierten Informations- und Wissensmanagements.'}], 'verstehen': [{'english': 'You understand the key platforms for knowledge transfer and know which information needs to be shared with whom.', 'german': 'Sie verstehen die wesentlichen Plattformen für den Wissen-Transfer und wissen, welche Informationen an wen weitergegeben werden müssen.'}], 'anwenden': [{'english': 'You are able to define storage structures and documentation guidelines for projects, and can provide relevant information at the right place.', 'german': 'Sie sind in der Lage, Ablagestrukturen und Dokumentationsrichtlinien für Projekte zu definieren und können die relevanten Informationen an der entsprechenden Stelle zur Verfügung stellen.'}], 'beherrschen': [{'english': 'You can define a comprehensive information management process.', 'german': 'Sie können einen umfangreichen Informationsmanagementprozess definieren.'}]}}
#
# Inserted indicators for competency 'Information Management'
#
# Competency 16 JSON Output:
# {'competency_name': 'Konfigurationsmanagement', 'indicators': {'kennen': [{'english': 'You are aware of the necessity of configuration management.', 'german': 'Sie verstehen die Notwendigkeit des Konfigurationsmanagements.'}, {'english': 'You know which tools are used to create configurations.', 'german': 'Sie wissen, in welchen Werkzeugen Konfigurationen zu bilden sind.'}], 'verstehen': [{'english': 'You understand the process of defining configuration items and can identify those relevant to you.', 'german': 'Sie verstehen das Vorgehen zur Festlegung von Konfigurationsitems und können die für Sie relevanten erkennen.'}, {'english': 'You are able to use the tools necessary to create configurations for your scopes.', 'german': 'Sie sind in der Lage, in den entsprechenden Werkzeugen Konfigurationen für Ihre Bereiche zu bilden.'}], 'anwenden': [{'english': 'You can define sensible configuration items and recognize those relevant to you.', 'german': 'Sie können sinnvolle Konfigurationsitems definieren und die für Sie relevanten erkennen.'}, {'english': 'You are capable of using tools to define configuration items and create configurations for your scopes.', 'german': 'Sie sind fähig, in den Werkzeugen Konfigurationsitems zu definieren und für Ihre Bereiche eine Konfiguration zu bilden.'}], 'beherrschen': [{'english': 'You are able to recognize all relevant configuration items and create a comprehensive configuration across all items.', 'german': 'Sie sind fähig, alle relevanten Konfigurationsitems zu erkennen und eine integre Konfiguration über alle Konfigurationsitems zu bilden.'}, {'english': 'You can identify improvements, propose solutions, and assist others in configuration management.', 'german': 'Sie können Verbesserungen identifizieren, Lösungsvorschläge herausarbeiten und andere bei der Bildung von Konfigurationen unterstützen.'}]}}
#
# Inserted indicators for competency 'Configuration Management'
# Skipping row 17 as it is 'Implementierung'

# %%
# Close the cursor and connection
cur.close()
conn.close()
